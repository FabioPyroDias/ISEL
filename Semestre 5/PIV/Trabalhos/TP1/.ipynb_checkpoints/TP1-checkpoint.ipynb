# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## Auxiliar Methods

# %%
def showImage(imageTitle, image):
    cv2.imshow(imageTitle, image)
    cv2.waitKey()
    cv2.destroyAllWindows()
    
def showImageArray(tituloArray, arrayImagens):
    for index in range(len(arrayImagens)):
        showImage(tituloArray + ": " + str(index), arrayImagens[index])

# %% [markdown]
# ## Caracteristicas Imagens

# %%
numberOfImages = 9
width = 768
height = 1024

# %% [markdown]
# ## Carregar Imagens Originais

# %%
imagesOriginal = [None] * numberOfImages
initialIndex = 1000697
currentIndex = initialIndex

for index in range(numberOfImages):
    while imagesOriginal[index] is None:
        imagesOriginal[index] = cv2.imread("P" + str(currentIndex) + "s.jpg")
        currentIndex = currentIndex + 1
        
# showImageArray("Imagem Original", imagesOriginal)

# %% [markdown]
# ## Obter Imagens Grayscale

# %%
imagesGrayscale = [None] * numberOfImages

for index in range(numberOfImages):
    imagesGrayscale[index] = cv2.cvtColor(imagesOriginal[index], cv2.COLOR_BGR2GRAY)
    
# showImageArray("Imagem Grayscale", imagesGrayscale)

# %% [markdown]
# ## Obter Thresholds e Imagens Binárias

# %%
imagesBinary = [None] * numberOfImages
imagesThresholds = [None] * numberOfImages

for index in range(numberOfImages):
    imagesThresholds[index], imagesBinary[index] = cv2.threshold(imagesGrayscale[index], 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# showImageArray("Imagem Binaria", imagesBinary)

# %% [markdown]
# # TESTES

# %%
imagemBinaria = imagesBinary[0]

#Melhorar a imagem
mascara5x5 = np.ones((5, 5), np.uint8)
mascara5x5[0, 0] = 0
mascara5x5[0, 4] = 0
mascara5x5[4, 0] = 0
mascara5x5[4, 4] = 0

mascara7x7 = np.ones((7, 7), np.uint8)
mascara7x7[0, 0] = 0
mascara7x7[0, 6] = 0
mascara7x7[6, 0] = 0
mascara7x7[6, 6] = 0

mascara9x9 = np.ones((9, 9), np.uint8)
mascara9x9[0, 0] = 0
mascara9x9[0, 8] = 0
mascara9x9[8, 0] = 0
mascara9x9[8, 8] = 0

#Erosão
# erosao1 = cv2.erode(imagemBinaria, mascara5x5, iterations = 1)
# erosao2 = cv2.erode(imagemBinaria, mascara5x5, iterations = 10)
# erosao3 = cv2.erode(imagemBinaria, mascara5x5, iterations = 30)
# erosao4 = cv2.erode(imagemBinaria, mascara5x5, iterations = 50)

#erosao = [erosao1, erosao2, erosao3, erosao4]


#showImageArray("Erosao", erosao)

#Fecho
fechoV1 = cv2.morphologyEx(imagemBinaria, cv2.MORPH_CLOSE, mascara5x5)
fechoV2 = cv2.morphologyEx(fechoV1, cv2.MORPH_CLOSE, mascara5x5)
fechoV3 = cv2.morphologyEx(fechoV2, cv2.MORPH_CLOSE, mascara5x5)

#fecho = [fechoV1, fechoV2, fechoV3] #Várias iterações não tem efeito

fecho5X5 = cv2.morphologyEx(imagemBinaria, cv2.MORPH_CLOSE, mascara5x5)
fecho7X7 = cv2.morphologyEx(imagemBinaria, cv2.MORPH_CLOSE, mascara7x7)
fecho9X9 = cv2.morphologyEx(imagemBinaria, cv2.MORPH_CLOSE, mascara9x9)

##Visualizar as Imagens
#showImage("Binária", imagemBinaria)

imagemBinariaColada = imagesBinary[4]
fecho9X9 = cv2.morphologyEx(imagemBinariaColada, cv2.MORPH_CLOSE, mascara9x9)
contours, hierarchy = cv2.findContours(fecho9X9, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
im = cv2.drawContours(imagesOriginal[4], contours, -1, (0,255,0), 3)

#showImage("", im)

# showImageArray("Erosao", erosao)
# showImageArray("Fecho 5x5", fecho)
# showImage("Fecho 5X5", fecho5X5)
# showImage("Fecho 7X7", fecho7X7)
# showImage("Fecho 9X9", fecho9X9)

imagemBinariaColada = imagesBinary[4]
#showImage("Bin Problema", imagemBinariaColada)


fecho5X5 = cv2.morphologyEx(imagemBinariaColada, cv2.MORPH_CLOSE, mascara5x5)
fecho7X7 = cv2.morphologyEx(imagemBinariaColada, cv2.MORPH_CLOSE, mascara7x7)
fecho9X9 = cv2.morphologyEx(imagemBinariaColada, cv2.MORPH_CLOSE, mascara9x9)

#showImage("Fecho5X5", fecho5X5)
#showImage("Fecho7X7", fecho7X7)
#showImage("Fecho9X9", fecho9X9)

#O engenheiro disse-me para usar a dilatação também com os discos.

dilatacao5X5 = cv2.dilate(imagemBinariaColada, mascara5x5, iterations=1)
fecho5X5 = cv2.morphologyEx(dilatacao5X5, cv2.MORPH_CLOSE, mascara5x5)

# showImage("Dilatacao", dilatacao5X5)
# showImage("Dilatacao + Fecho", fecho5X5)

erosao1 = cv2.erode(dilatacao5X5, mascara5x5, iterations = 1)
#showImage("Erosao", erosao1)

fecho5X5 = cv2.morphologyEx(imagemBinariaColada, cv2.MORPH_CLOSE, mascara5x5)
dilatacao5X5 = cv2.dilate(fecho5X5, mascara5x5, iterations=1)

# showImage("Fecho", fecho5X5)
# showImage("Fecho + Dilatacao", dilatacao5X5)

# %% [markdown]
# # V2
#
# Ideia básica:<br>
# Agarramos na primeira imagem onde temos todas as moedas bem dispersas.<br>
# Corrigimos as moedas com as máscaras.<br>
# Separamo-las.<br>
# Fazemos máscaras para cada uma.<br>
# A partir disto, percorremos as imagens todas e procuramos correspondências às mesmas.<br>
#
# Não esquecer de caracterizar os valores das moedas.
# Atribuir gamas de valores à característica.

# %%
mask = np.ones((9, 9), np.uint8)
mask[0, 0] = 0
mask[0, 8] = 0
mask[8, 0] = 0
mask[8, 8] = 0

#Imagem após a Operação Morfológica
filledImage = cv2.morphologyEx(imagemBinaria, cv2.MORPH_CLOSE, mask)
erodedImage = cv2.morphologyEx(filledImage, cv2.MORPH_OPEN, mask)

ret, thresh = cv2.threshold(erodedImage, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU) 

#imagesThresholds = np.asarray(imagesThresholds, dtype=np.uint8)

#Próximo passo, separar objectos
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
image = cv2.drawContours(erodedImage, contours, -1, (255, 255, 255), 3)
#connectedComponents

# showImage("bin", imagesBinary[0])
# showImage("Filled", erodedImage)
# showImage("Contour Filled", image)

#num_labels, labels_im = cv2.connectedComponents(image)
#labels_im = np.asarray(labels_im, dtype=np.uint8)
#labels_im[labels_im != 0] = 255

numLabels, labels, stats, centroids = cv2.connectedComponentsWithStats(thresh, 8, cv2.CV_32S)

#Pelo que percebi, o numLabel = 0 é o fundo preto.
#A partir dai, já são os objectos

# print(numLabels)
# print()
# print(labels)
# print()
# print(stats)

initialPointX = stats[1, cv2.CC_STAT_LEFT]
initialPointY = stats[1, cv2.CC_STAT_TOP]
width = stats[1, cv2.CC_STAT_WIDTH]
height = stats[1, cv2.CC_STAT_HEIGHT]
area = stats[1, cv2.CC_STAT_AREA]
(centroidX, centroidY) = centroids[1]

#rect = cv2.rectangle(output, (initialPointX, initialPointY), (initialPointX + width, initialPointY + height), (255, 255, 255), 1)
#circle = cv2.circle(output, (int(centroidX), int(centroidY)), 1, (255, 0, 255), -1)

componentMask = (labels == 1).astype(np.uint8) * 255
print(initialPointX)
print(initialPointY)
print(width)
print(height)

#Não consigo cortar a imagem como era suposto
#componentMask = erodedImage[initialPointX : initialPointX + width, initialPointY : initialPointY + height]

print(componentMask)

#showImage("Bin", imagemBinaria)
#showImage("Filled", filledImage)
#showImage("Filled", labels_im)
# cv2.imshow("Eroded", erodedImage)
# cv2.imshow("Mask", componentMask)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# # Para o Engenheiro

# %%
import numpy as np
import cv2

def showImage(imageTitle, image):
    cv2.imshow(imageTitle, image)
    cv2.waitKey()
    cv2.destroyAllWindows()

#Carregar Imagem Original, Converter para GrayScale e depois para Binaria
imagemOriginal = cv2.imread("P1000697s.jpg")
imagemGrayscale = cv2.cvtColor(imagemOriginal, cv2.COLOR_BGR2GRAY)
threshold, imagemBinaria = cv2.threshold(imagemGrayscale, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

#Elemento Estruturante Disco(9)
mask = np.ones((9, 9), np.uint8)
mask[0, 0] = 0
mask[0, 8] = 0
mask[8, 0] = 0
mask[8, 8] = 0

#Imagem após a Operação Morfológica
filledImage = cv2.morphologyEx(imagemBinaria, cv2.MORPH_CLOSE, mask)
erodedImage = cv2.morphologyEx(filledImage, cv2.MORPH_OPEN, mask)

#Preciso de atualizar o threshold para o findContours e connectedComponentsWithStats
ret, thresh = cv2.threshold(erodedImage, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU) 

#Próximo passo, separar objectos
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
image = cv2.drawContours(erodedImage, contours, -1, (255, 255, 255), 3)

#
numLabels, labels, stats, centroids = cv2.connectedComponentsWithStats(thresh, 8, cv2.CV_32S)

#labels[0] é o fundo (tudo preto)
initialPointX = stats[1, cv2.CC_STAT_LEFT]
initialPointY = stats[1, cv2.CC_STAT_TOP]
width = stats[1, cv2.CC_STAT_WIDTH]
height = stats[1, cv2.CC_STAT_HEIGHT]
area = stats[1, cv2.CC_STAT_AREA]
(centroidX, centroidY) = centroids[1]

componentMask = (labels == 1).astype(np.uint8) * 255
#print(initialPointX)
#print(initialPointY)
#print(width)
#print(height)

#IMPORTANTE!
#O corte tem de ser y's e depois x's e não o convencional [x, y]
componentMaskCut = erodedImage[initialPointY : initialPointY + height, initialPointX : initialPointX + width]

print(area)
raio = width #Isto é o diametro, teoricamente
print(width)
print(raio)


#getStructuralElement
disco = cv2.MORPH_ELLIPSE
size = (int(raio), int(raio))
elementoEstruturante = cv2.getStructuringElement(disco, size)
elementoEstruturante = elementoEstruturante * 255

print("CMK", componentMaskCut.shape)
print("EE", elementoEstruturante.shape)

#Teste da operação AND

rectangle = np.zeros((148, 148), dtype="uint8")
cv2.rectangle(rectangle, (24, 24), (124, 124), 255, -1)
#cv2.imshow("Rectangle", rectangle)


result = cv2.bitwise_and(componentMaskCut[1:,:], elementoEstruturante)
#cv2.imshow("Coin", result)
#cv2.waitKey(0)
result = cv2.bitwise_and(rectangle, elementoEstruturante)
#cv2.imshow("Square", result)

#--------------------
# Perform template matching
result = cv2.matchTemplate(erodedImage, elementoEstruturante, cv2.TM_CCOEFF_NORMED)

# Define a threshold to determine confidence in matches
threshold = 0.9

# Find the locations where the result is above the threshold
locations = np.where(result >= threshold)

print(locations)


#cv2.imshow("", componentMaskCut)
#cv2.imshow("Elemento Estruturante", elementoEstruturante)
#a = erodedImage[initialPointX - 100 : initialPointX + 100, initialPointY - 100 : initialPointY + 100]
#print(a)
#print(erodedImage)
#print("Sum Eroded: ", np.sum(erodedImage==255))
#b = componentMask[initialPointX : initialPointX + width, initialPointY : initialPointY + height]
#print(b == 255)
#print("Sum: ", np.sum(componentMask==255))

#cv2.imshow("Mascara Moeda Isolada", erodedImage)
#cv2.imshow("Mascara Moeda Isolada", componentMask)
#cv2.imshow("Mascara Moeda Isolada", componentMaskCut)
#cv2.imshow("Teste", teste)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# #### Características da Primeira Imagem

# %%
valorMoedas = [0.05, 0.01, 0.50, 0.02, 0.10, 0.20, 1]
diametroMascaraMoedas = np.zeros(len(valorMoedas), np.uint8)

for componenteIndex in range(numLabels):
    if componenteIndex != 0 and componenteIndex != 7:    
        #Características dos componentes
        initialPointX = stats[componenteIndex, cv2.CC_STAT_LEFT]
        initialPointY = stats[componenteIndex, cv2.CC_STAT_TOP]
        width = stats[componenteIndex, cv2.CC_STAT_WIDTH]
        height = stats[componenteIndex, cv2.CC_STAT_HEIGHT]
        area = stats[componenteIndex, cv2.CC_STAT_AREA]
        (centroidX, centroidY) = centroids[componenteIndex]
        
        #Isolar o componente
        moedaOriginal = imagesOriginal[0][initialPointY : initialPointY + height, initialPointX : initialPointX + width]
        componentMaskCut = erodedImage[initialPointY : initialPointY + height, initialPointX : initialPointX + width]
        
        #cv2.imshow("Moeda " + str(componenteIndex), moedaOriginal)
        
        #Obter o Elemento Estruturante do Tamanho do Componente
        disco = cv2.MORPH_ELLIPSE
        size = (int(width), int(width))
        elementoEstruturante = cv2.getStructuringElement(disco, size) * 255
        
        #cv2.imshow("Elemento Estruturante Resultante " + str(componenteIndex), elementoEstruturante)
        cv2.waitKey(0)
        cv2.destroyAllWindows()
        
        #Adicionar o tamanho da Moeda ao array
        if componenteIndex == 8:
            diametroMascaraMoedas[componenteIndex - 2] = int(width)
        else:
            diametroMascaraMoedas[componenteIndex - 1] = int(width)

# %% [markdown]
# #### Observação de Resultados

# %%
print("Valor das Moedas: ", valorMoedas)
print("Diametro das Moedas: ", diametroMascaraMoedas)

# %% [markdown]
# #### Teste para a primeira Imagem

# %%
imagemOriginal = cv2.imread("P1000697s.jpg")
imagemGrayscale = cv2.cvtColor(imagemOriginal, cv2.COLOR_BGR2GRAY)
threshold, imagemBinaria = cv2.threshold(imagemGrayscale, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

#Elemento Estruturante Disco(9)
mask = np.ones((9, 9), np.uint8)
mask[0, 0] = 0
mask[0, 8] = 0
mask[8, 0] = 0
mask[8, 8] = 0

#Imagem após a Operação Morfológica
filledImage = cv2.morphologyEx(imagemBinaria, cv2.MORPH_CLOSE, mask)
erodedImage = cv2.morphologyEx(filledImage, cv2.MORPH_OPEN, mask)

#Preciso de atualizar o threshold para o findContours e connectedComponentsWithStats
ret, thresh = cv2.threshold(erodedImage, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU) 

#Próximo passo, separar objectos
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
image = cv2.drawContours(erodedImage, contours, -1, (255, 255, 255), 3)

#
numLabels, labels, stats, centroids = cv2.connectedComponentsWithStats(thresh, 8, cv2.CV_32S)

valorRealNaImagem = 2.08
valorNaImagemObtido = 0

#Valores dos componentes por ordem
ordem = [0.05, 0.01, 0.50, 0.02, 0.10, 0.20, 0.20, 1]        

#Analise de cada Componente
for componenteIndex in range(numLabels):
    if componenteIndex != 0:
        
        #Características dos componentes
        initialPointX = stats[componenteIndex, cv2.CC_STAT_LEFT]
        initialPointY = stats[componenteIndex, cv2.CC_STAT_TOP]
        width = stats[componenteIndex, cv2.CC_STAT_WIDTH]
        height = stats[componenteIndex, cv2.CC_STAT_HEIGHT]
        area = stats[componenteIndex, cv2.CC_STAT_AREA]
        (centroidX, centroidY) = centroids[componenteIndex]
        
        #Isolar o componente
        componentMaskCut = erodedImage[initialPointY : initialPointY + height, initialPointX : initialPointX + width]
        
        #Definir um limiar de aceitação do padrão 
        threshold = 0.9
        
        #Guardar as posições previamente descobertas
        pointXBefore = -1
        pointYBefore = -1
        
        print("Avaliação do valor ", ordem[componenteIndex - 1])
        
        #Avaliação do Componente
        for mascaraIndex in range(len(valorMoedas)):
            disco = cv2.MORPH_ELLIPSE
            size = (diametroMascaraMoedas[mascaraIndex], diametroMascaraMoedas[mascaraIndex])
            elementoEstruturante = cv2.getStructuringElement(disco, size) * 255
        
            #Procura padrão nas Imagem
            result = cv2.matchTemplate(erodedImage, elementoEstruturante, cv2.TM_CCOEFF_NORMED)

            #Encontrar as localizações.
            locations = np.where(result >= threshold)
        
            #Comparação de cada máscara das moedas preparadas com a moeda real.
            print("A comparar com máscara do valor ", valorMoedas[mascaraIndex])
            print("Localizações encontradas: ", locations)
            print()
        
            for locationIndex in range(len(locations[0])):
                
                if(locations[0][locationIndex] - pointXBefore > width or locations[1][locationIndex] - pointYBefore > height):
                    
                    if(diametroMascaraMoedas[mascaraIndex] >= width - 5 and diametroMascaraMoedas[mascaraIndex] <= width + 5):
                        valorNaImagemObtido = valorNaImagemObtido + valorMoedas[mascaraIndex]
                
                        pointXBefore = locations[0][locationIndex]
                        pointYBefore = locations[1][locationIndex]
                        
                        print("Adicionado ", valorMoedas[mascaraIndex])
            
        print("Fim da avaliação do valor ", ordem[componenteIndex - 1])
        print()

print("Valor Real Na Imagem: ", valorRealNaImagem)
print("Valor Obtido Na Imagem: ", valorNaImagemObtido)

# %%
print(valorMoedas[2], " Diâmetro: ", diametroMascaraMoedas[1], "gama de diametro: ", diametroMascaraMoedas[1] - 5, diametroMascaraMoedas[1] + 5)

print("Na imagem:")
print("Diametro:", stats[2, cv2.CC_STAT_WIDTH])

#cv2.imshow("Original", imagesOriginal[0])
#cv2.imshow("Eroded", erodedImage)
#cv2.imshow("Mascara moeda 0.01", erodedImage[initialPointY : initialPointY + height, initialPointX : initialPointX + width])
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %% [markdown]
# ### Primeira Imagem

# %%
mask = np.ones((9, 9), np.uint8)
mask[0, 0] = 0
mask[0, 8] = 0
mask[8, 0] = 0
mask[8, 8] = 0

dilatedImage = cv2.dilate(imagesBinary[0], mask, iterations=1)
filledImage = cv2.morphologyEx(dilatedImage, cv2.MORPH_CLOSE, mask)
erodedImage = cv2.morphologyEx(filledImage, cv2.MORPH_OPEN, mask)

#Ordem Contrária para aparecerem primeiro
#cv2.imshow("Erodida", erodedImage)
#cv2.imshow("Preenchida", filledImage)
#cv2.imshow("Dilatada", dilatedImage)
#cv2.imshow("Binaria", imagesBinary[0])
#cv2.imshow("Original", imagesOriginal[0])
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %% [markdown]
# ### Terceira Imagem

# %%
# mask5X5 = np.ones((5, 5), np.uint8)
# mask5X5[0, 0] = 0
# mask5X5[0, 4] = 0
# mask5X5[4, 0] = 0
# mask5X5[4, 4] = 0

# mask7X7 = np.ones((7, 7), np.uint8)
# mask7X7[0, 0] = 0
# mask7X7[0, 6] = 0
# mask7X7[6, 0] = 0
# mask7X7[6, 6] = 0

# mask9X9 = np.ones((9, 9), np.uint8)
# mask9X9[0, 0] = 0
# mask9X9[0, 8] = 0
# mask9X9[8, 0] = 0
# mask9X9[8, 8] = 0

# maskSquare5X5 = np.ones((5, 5), np.uint8)
# maskSquare7X7 = np.ones((7, 7), np.uint8)
# maskSquare9X9 = np.ones((9, 9), np.uint8)

# #------------------------------------------------------------------------
# #Ordem: Dilatar, Preencher, Erodir
# dilatedImage = cv2.dilate(imagesBinary[2], mask5X5, iterations=1)
# filledImage = cv2.morphologyEx(dilatedImage, cv2.MORPH_CLOSE, mask9X9)
# erodedImage = cv2.morphologyEx(filledImage, cv2.MORPH_OPEN, mask9X9)

# ret, thresh = cv2.threshold(erodedImage, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU) 
# numLabels, labels, stats, centroids = cv2.connectedComponentsWithStats(thresh, 8, cv2.CV_32S)
# print("1 - ", numLabels)

# #Ordem Contrária para aparecerem primeiro
# # cv2.imshow("Erodida", erodedImage)
# # cv2.imshow("Preenchida", filledImage)
# # cv2.imshow("Dilatada", dilatedImage)
# # cv2.imshow("Binaria", imagesBinary[2])
# # cv2.imshow("Original", imagesOriginal[2])
# # cv2.waitKey(0)
# # cv2.destroyAllWindows()
# #------------------------------------------------------------------------

# #------------------------------------------------------------------------ ->
# #Ordem: Erodir, Dilatar, Preencher
# erodedImage = cv2.morphologyEx(imagesBinary[2], cv2.MORPH_OPEN, mask5X5)
# dilatedImage = cv2.dilate(erodedImage, mask9X9, iterations=1)
# filledImage = cv2.morphologyEx(dilatedImage, cv2.MORPH_CLOSE, mask9X9)

# ret, thresh = cv2.threshold(filledImage, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU) 
# numLabels, labels, stats, centroids = cv2.connectedComponentsWithStats(thresh, 8, cv2.CV_32S)
# print("2 - ", numLabels)

# erodedImage = cv2.morphologyEx(imagesBinary[2], cv2.MORPH_OPEN, mask5X5)
# dilatedImage = cv2.dilate(erodedImage, mask9X9, iterations=1)
# filledImage = cv2.morphologyEx(dilatedImage, cv2.MORPH_CLOSE, mask9X9)

# ret, thresh = cv2.threshold(filledImage, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU) 
# numLabels, labels, stats, centroids = cv2.connectedComponentsWithStats(thresh, 8, cv2.CV_32S)
# print("2 - ", numLabels)

# erodedImage = cv2.morphologyEx(imagesBinary[2], cv2.MORPH_OPEN, mask5X5)
# dilatedImage = cv2.dilate(erodedImage, mask9X9, iterations=1)
# filledImage = cv2.morphologyEx(dilatedImage, cv2.MORPH_CLOSE, mask9X9)

# ret, thresh = cv2.threshold(filledImage, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU) 
# numLabels, labels, stats, centroids = cv2.connectedComponentsWithStats(thresh, 8, cv2.CV_32S)
# print("2 - ", numLabels)

# erodedImage = cv2.morphologyEx(imagesBinary[2], cv2.MORPH_OPEN, mask5X5)
# dilatedImage = cv2.dilate(erodedImage, mask9X9, iterations=1)
# filledImage = cv2.morphologyEx(dilatedImage, cv2.MORPH_CLOSE, mask9X9)

# ret, thresh = cv2.threshold(filledImage, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU) 
# numLabels, labels, stats, centroids = cv2.connectedComponentsWithStats(thresh, 8, cv2.CV_32S)
# print("2 - ", numLabels)


# # cv2.imshow("Preenchida", filledImage)
# # cv2.imshow("Dilatada", dilatedImage)
# # cv2.imshow("Erodida", erodedImage)
# # cv2.imshow("Binaria", imagesBinary[2])
# # cv2.imshow("Original", imagesOriginal[2])
# # cv2.waitKey(0)
# # cv2.destroyAllWindows()
# #------------------------------------------------------------------------

# #------------------------------------------------------------------------
# #Ordem: Dilatar, Preencher
# dilatedImage = cv2.dilate(imagesBinary[2], mask5X5, iterations=1)
# filledImage = cv2.morphologyEx(dilatedImage, cv2.MORPH_CLOSE, mask9X9)

# ret, thresh = cv2.threshold(filledImage, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU) 
# numLabels, labels, stats, centroids = cv2.connectedComponentsWithStats(thresh, 8, cv2.CV_32S)
# print("3 - ", numLabels)

# # cv2.imshow("Preenchida", filledImage)
# # cv2.imshow("Dilatada", dilatedImage)
# # cv2.imshow("Binaria", imagesBinary[2])
# # cv2.imshow("Original", imagesOriginal[2])
# # cv2.waitKey(0)
# # cv2.destroyAllWindows()
# #------------------------------------------------------------------------


# #ret, thresh = cv2.threshold(imagesGrayscale[2], 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU) 
# #ret, thresh = cv2.threshold(imagesGrayscale[2], 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C)
# numLabels, labels, stats, centroids = cv2.connectedComponentsWithStats(thresh, 8, cv2.CV_32S)

# #------------------------------------------------------------------------
# #Ordem: Dilatar, Preencher


# for index in range(len(imagesOriginal)):
    
#     blur = cv2.GaussianBlur(imagesGrayscale[index],(3, 3),0)
#     ret, imageBinaryTest = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU) 

#     imageDilated5X5 = cv2.dilate(imageBinaryTest, mask5X5, iterations=1)
#     imageFilled5X5 = cv2.morphologyEx(imageBinaryTest, cv2.MORPH_CLOSE, mask5X5)
#     imageFilled7X7 = cv2.morphologyEx(imageBinaryTest, cv2.MORPH_CLOSE, mask7X7)
#     imageFilled9X9 = cv2.morphologyEx(imageBinaryTest, cv2.MORPH_CLOSE, mask9X9)
    
#     imageDilated5X5Square = cv2.dilate(imageBinaryTest, maskSquare5X5, iterations=1)
#     imageFilled5X5Square = cv2.morphologyEx(imageBinaryTest, cv2.MORPH_CLOSE, maskSquare5X5)
#     imageFilled7X7Square = cv2.morphologyEx(imageBinaryTest, cv2.MORPH_CLOSE, maskSquare7X7)
#     imageFilled9X9Square = cv2.morphologyEx(imageBinaryTest, cv2.MORPH_CLOSE, maskSquare9X9)
    
#     #cv2.imshow("Image Binary " + str(index), imageBinaryTest)
# #     cv2.imshow("Image Dilated " + str(index), imageDilated5X5)
#     #cv2.imshow("Image Dilated Square " + str(index), imageDilated5X5Square)
# #     cv2.imshow("Image Filled 5X5 | " + str(index), imageFilled5X5)
# #     cv2.imshow("Image Filled 7X7 | " + str(index), imageFilled7X7)
# #     cv2.imshow("Image Filled 9X9 | " + str(index), imageFilled9X9)
#     #cv2.imshow("Image Filled 5X5 Square | " + str(index), imageFilled5X5Square)
#     #cv2.imshow("Image Filled 7X7 Square | " + str(index), imageFilled7X7Square)
#     #cv2.imshow("Image Filled 9X9 Square | " + str(index), imageFilled9X9Square)
# #    cv2.waitKey(0)
# #    cv2.destroyAllWindows()

# #Valor das Moedas:  [0.05, 0.01, 0.5, 0.02, 0.1, 0.2, 1]

# for index in range(len(valorMoedas)):

    
#     disco = cv2.MORPH_ELLIPSE
#     size = (diametroMascaraMoedas[index], diametroMascaraMoedas[index])
#     elementoEstruturante = cv2.getStructuringElement(disco, size) * 255
    
#     negativeSize = (diametroMascaraMoedas[index] - 2, diametroMascaraMoedas[index] - 2)
#     elementoEstruturanteNegativo = 255 - cv2.getStructuringElement(disco, negativeSize) * 255
    
#     imagemMascara = np.zeros([diametroMascaraMoedas[index], diametroMascaraMoedas[index]], np.uint8)
#     a = cv2.circle(imagemMascara, (diametroMascaraMoedas[index] / 2, diametroMascaraMoedas[index] / 2), diametroMascaraMoedas[index] / 2, (255, 255, 255), 2)
    
#     resultado = elementoEstruturante & elementoEstruturanteNegativo
    
#     #showImage(" ", elementoEstruturanteNegativo)
#     #showImage(" | ", a)

    
#     b = cv2.morphologyEx(imageDilated5X5, cv2.MORPH_CLOSE, resultado)
#     #showImage(" ", elementoEstruturanteNegativo)
    
#     #showImage(str(valorMoedas[index]), b)
    
# imageDilated5X5 = cv2.dilate(imageBinaryTest, mask5X5, iterations=1)
# imageDilated7X7 = cv2.dilate(imageBinaryTest, mask7X7, iterations=1)
# imageDilated9X9 = cv2.dilate(imageBinaryTest, mask9X9, iterations=1)
# imageFilled = cv2.morphologyEx(imageBinaryTest, cv2.MORPH_CLOSE, mask9X9)

# imageDilated5X5Filled = cv2.morphologyEx(imageDilated5X5, cv2.MORPH_CLOSE, mask5X5)
# imageDilated7X7Filled = cv2.morphologyEx(imageDilated7X7, cv2.MORPH_CLOSE, mask7X7)
# imageDilated9X9Filled = cv2.morphologyEx(imageDilated9X9, cv2.MORPH_CLOSE, mask9X9)
# imageFilledDilated5X5 = cv2.dilate(imageFilled, mask5X5, iterations=1)

# # cv2.imshow("Binary Test", imageBinaryTest)
# # cv2.imshow("Dilated 5X5 Test", imageDilated5X5)
# # cv2.imshow("Dilated 7X7 Test", imageDilated7X7)
# # cv2.imshow("Dilated 9X9 Test", imageDilated9X9)
# # cv2.imshow("Filled Test", imageFilled)
# # cv2.waitKey(0)
# # cv2.destroyAllWindows()

# # cv2.imshow("Dilated 5X5 Filled Test", imageDilated5X5Filled)
# # cv2.imshow("Dilated 7x7 Filled Test", imageDilated7X7Filled)
# # cv2.imshow("Dilated 9x9 Filled Test", imageDilated9X9Filled)
# # cv2.imshow("Filled Dilated 5X5 Test", imageFilledDilated5X5)
# # cv2.waitKey(0)
# # cv2.destroyAllWindows()

# #dilatedImage = cv2.dilate(imagesBinary[2], mask5X5, iterations=1)
# #filledImage = cv2.morphologyEx(dilatedImage, cv2.MORPH_CLOSE, mask9X9)

# ret, thresh = cv2.threshold(filledImage, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU) 
# numLabels, labels, stats, centroids = cv2.connectedComponentsWithStats(thresh, 8, cv2.CV_32S)
# print("4 - ", numLabels)

# # cv2.imshow("Preenchida", filledImage)
# # cv2.imshow("Dilatada", dilatedImage)
# # cv2.imshow("Binaria", imagesBinary[2])
# # cv2.imshow("Original", imagesOriginal[2])
# # cv2.waitKey(0)
# # cv2.destroyAllWindows()
# #------------------------------------------------------------------------

# a = cv2.adaptiveThreshold(imagesGrayscale[2],255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,11,2)
# #showImage("", a)

# %% [markdown]
# # Testes com o ChatGPT

# %% [markdown]
# Valor das Moedas:  [0.05, 0.01, 0.5, 0.02, 0.1, 0.2, 1]
#
# Diametro das Moedas:  [148 113 170 134 139 158 163]

# %%
def showImage(title, image, waitKey):
    cv2.imshow(title, image)
    
    if waitKey:
        cv2.waitKey(0)
        cv2.destroyAllWindows()

# %%
import numpy as np
import cv2

### Imagens Originais
numberOfImages = 9
imagensOriginais = [None] * numberOfImages
initialIndex = 1000697
currentIndex = initialIndex

for index in range(numberOfImages):
    while imagensOriginais[index] is None:
        imagensOriginais[index] = cv2.imread("P" + str(currentIndex) + "s.jpg")
        currentIndex = currentIndex + 1

### Imagens Grayscale
imagensGrayscale = [None] * numberOfImages

for index in range(numberOfImages):
    imagensGrayscale[index] = cv2.cvtColor(imagensOriginais[index], cv2.COLOR_BGR2GRAY)
        
### Equalização Histograma
imagensEqualizacao = [None] * numberOfImages

for index in range(numberOfImages):
    imagensEqualizacao[index] = cv2.equalizeHist(imagensGrayscale[index])

#1 Imagem
#clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
#e = clahe.apply(imagensGrayscale[0])
#thresh, imagemBinaria = cv2.threshold(imagensEqualizacao[0], 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
#thresh, imagemBinariaClahe = cv2.threshold(imagensEqualizacao[0], 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
#blurred = cv2.GaussianBlur(imagensGrayscale[0], (5, 5), 0)

#showImage("Imagem Binaria", imagemBinariaClahe, True)



##### Não funciona
# circlesEqualizacao = cv2.HoughCircles(imagensEqualizacao[0], cv2.HOUGH_GRADIENT, 1.2, 20, minRadius=50, maxRadius=180)

# circlesCopy = imagensOriginais[0].copy()

# if circlesEqualizacao is not None:
#     circlesEqualizacao = np.round(circlesEqualizacao[0, :]).astype("int")
    
#     for (x, y, r) in circlesEqualizacao:
#         cv2.circle(circlesCopy, (x, y), r, (0, 0, 0), 4)

# showImage("Imagem Circles Equalizacao", circlesCopy, True)



# showImage("Imagem Equalizacao", imagensEqualizacao[0], False)
# showImage("Imagem Apply", e, False)
# showImage("Imagem Binaria", imagemBinaria, False)
# showImage("Imagem Blurred", blurred, True)

# circlesEqualize = cv2.HoughCircles(imagensEqualizacao[0], cv2.HOUGH_GRADIENT, 1.2, 100)
# circlesClahe = cv2.HoughCircles(e, cv2.HOUGH_GRADIENT, 1.2, 100)
# circlesBinaria = cv2.HoughCircles(imagemBinaria, cv2.HOUGH_GRADIENT, 1.2, 100)
# circlesBlurred = cv2.HoughCircles(blurred, cv2.HOUGH_GRADIENT, 1.2, 100) 

# #Equalize
# outputCirclesEqualize = imagensOriginais[0].copy()

# if circlesEqualize is not None:
#     circlesEqualize = np.round(circlesEqualize[0, :]).astype(np.uint8)
    
#     for (x, y, r) in circlesEqualize:
#         cv2.circle(outputCirclesEqualize, (x, y), r, (0, 0, 0), 4)

# #Clahe
# outputCirclesClahe = imagensOriginais[0].copy()

# if circlesClahe is not None:
#     circlesClahe = np.round(circlesClahe[0, :]).astype(np.uint8)
    
#     for (x, y, r) in circlesClahe:
#         cv2.circle(outputCirclesClahe, (x, y), r, (0, 0, 0), 4)

# #Binaria
# outputCirclesBinaria = imagensOriginais[0].copy()

# if circlesBinaria is not None:
#     circlesBinaria = np.round(circlesBinaria[0, :]).astype(np.uint8)
    
#     for (x, y, r) in circlesBinaria:
#         cv2.circle(outputCirclesBinaria, (x, y), r, (0, 0, 0), 4)

# #Blurred
# outputCirclesBlurred = imagensOriginais[0].copy()

# if circlesBlurred is not None:
#     circlesBlurred = np.round(circlesBlurred[0, :]).astype(np.uint8)
    
#     for (x, y, r) in circlesBlurred:
#         cv2.circle(outputCirclesBlurred, (x, y), r, (0, 0, 0), 4)
        

# showImage("Circles Equalize", outputCirclesEqualize, False)
# showImage("Circles Clahe", outputCirclesClahe, False)
# showImage("Circles Binaria", outputCirclesBinaria, False)
# showImage("Circles Blurred", outputCirclesBlurred, True)

# %%
### Impressao Imagens após Equalizacao 
# for index in range(numberOfImages):
    
#     if index != numberOfImages - 1:
#         showImage("Imagem " + str(index + 1), imagensEqualizacao[index], False)
#     else:
#         showImage("Imagem " + str(index + 1), imagensEqualizacao[index], True)

# %% [markdown]
# ### Isto oferece bons resultados na detecção de círculos

# %% [markdown]
# Valor das Moedas:  [0.05, 0.01, 0.5, 0.02, 0.1, 0.2, 1]
#
# Diametro das Moedas:  [148 113 170 134 139 158 163]

# %%
circlesGrayscale = cv2.HoughCircles(imagensGrayscale[0], cv2.HOUGH_GRADIENT, 1.3, 90, minRadius=50, maxRadius=240)
circlesCopy = imagensOriginais[0].copy()

if circlesGrayscale is not None:
    circlesGrayscale = np.round(circlesGrayscale[0, :]).astype("int")

    for (x, y, r) in circlesGrayscale:
        cv2.circle(circlesCopy, (x, y), r, (0, 0, 0), 4)
        #showImage("Imagem " + str(index), imagensOriginais[0][y - r : y + r, x - r : x + r], False)

# %%
#showImage("", imagensOriginais[0][411 - 79 : 411 + 79, 274 - 79 : 274 + 79], False)
#showImage("Imagem", imagensOriginais[0], False)

#Mascara
elementoEstruturante = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (79 * 2, 79 * 2)) * 255
#showImage("Elemento Estruturante", elementoEstruturante, True)

# %%
for index in range(numberOfImages):
    
    #circlesGrayscale = cv2.HoughCircles(imagensGrayscale[index], cv2.HOUGH_GRADIENT, 1.3, 90, minRadius=50, maxRadius=180)
    circlesGrayscale = cv2.HoughCircles(imagensGrayscale[index], cv2.HOUGH_GRADIENT, 1.3, 90, minRadius=50, maxRadius=240)
    circlesCopy = imagensOriginais[index].copy()

    if circlesGrayscale is not None:
        circlesGrayscale = np.round(circlesGrayscale[0, :]).astype("int")

        #showImage("", imagensOriginais[0][y - r : y + r, x - r : x + r], False)
        
        for (x, y, r) in circlesGrayscale:
            cv2.circle(circlesCopy, (x, y), r, (0, 0, 0), 4)
            #showImage("Imagem " + str(index), imagensOriginais[index][y - r : y + r, x - r : x + r], False)
            print(x,y,r)
        
            elementoEstruturante = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (r * 2, r * 2)) * 255
            #showImage("Elemento Estruturante", elementoEstruturante, True)
    #showImage("Imagem Circles Grayscale", circlesCopy, True)
    print()
    
    
    #showImage("20 centimos", circlesCopy[411 - 79 : 411 + 79, 274 - 79 : 274 + 79], False)
    #showImage("1 euro", circlesCopy[509 - 80 : 509 + 80, 660 - 80 : 660 + 80], True)

# %% [markdown]
# ### Observacoes

# %% [markdown]
# #### Ordem de deteccao dos circulos
#
# ##### Primeira Imagem
# 0 - 20 centimos -> Boa, Raio 79<br>
# 1 - 2 centimos -> Boa, Raio 67<br>
# 2 - 50 centimos -> Boa, Raio 85<br>
# 3 - 1 euro -> Quase Boa, Raio 80<br>
# 4 - 5 centimos -> Boa, Raio 74<br>
# 5 - 1 centimo -> Mal, Raio 57<br>
# 6 - 20 centimos -> Mal, Raio 75<br>
# 7 - 10 centimos -> Mal, Raio 65
#
# ##### Segunda Imagem
# 0 - 20 centimos -> Boa, Raio 78<br>
# 1 - 10 centimos -> Boa, Raio: 68<br>
# 2 - 1 euro -> Boa, Raio: 80<br>
# 3 - 2 centimos -> Boa, Raio 68<br>
# 4 - 1 centimo -> Mal, Raio: 54
#
# ##### Terceira Imagem
# 0 - 50 centimos -> Mal, Raio 80<br>
# 1 - 5 centimos -> Quase Boa, Raio 74<br>
# 2 - 20 centimos -> Quase Boa, Raio 74<br>
# 3 - 2 centimos -> Boa, Raio 64<br>
# 4 - 1 centimo -> Mal, Raio 56
#
# ##### Quarta Imagem
# 0 - 50 centimos -> Boa, Raio 84<br>
# 1 - 2 centimos -> Boa, Raio 67<br>
# 2 - 5 centimos -> Boa, Raio 73<br>
# 3 - 10 centimos -> Boa, Raio 67
#
# ##### Quinta Imagem
# 0 - 50 centimos -> Boa, Raio 85<br>
# 1 - 1 euro -> Boa, Raio 81<br>
# 2 - 10 centimos -> Quase Boa, Raio 67<br>
# 3 - 2 centimos -> Quase Boa, Raio 66<br>
#
# ##### Sexta Imagem
# 0 - 2 centimos -> Boa, Raio 67<br>
# 1 - 50 centimos -> Boa, Raio 84<br>
# 2 - 1 euro -> Quase Boa, Raio 79<br>
# 3 - 10 centimos -> Boa, Raio 68<br>
# 4 - 5 centimos -> Boa, Raio 75
#
# ##### Setima Imagem
# 0 - 1 euro -> Boa, Raio 81<br>
# 1 - 20 centimos -> Quase Boa, Raio 75<br>
# 2 - 10 centimos -> Boa, Raio 70<br>
# 3 - VAZIO -> Raio 125
#
# ##### Oitava Imagem
# 0 - 1 euro -> Quase Boa, Raio 80<br>
# 1 - 10 centimos -> Boa, Raio 70<br>
# 2 - 20 centimos -> Quase Boa, Raio 74<br>
# 3 - VAZIO -> Raio 166
#
# ##### Nona Imagem
# 0 - 50 centimos -> Boa, Raio 85<br>
# 1 - 20 centimos -> Boa, Raio 79 ------- Não sei se é de 50 ou de 20<br>
# 2 - 1 euro -> Quase Boa, Raio 76<br>

# %% [markdown]
# ### Conclusoes

# %% [markdown]
# ##### Moeda 1 Centimo
# Raio Maximo: 57<br>
# Raio Minimo: 54
#
# ##### Moeda 2 Centimos
# Raio Maximo: 68<br>
# Raio Minimo: 64
#
# ##### Moeda 5 Centimos
# Raio Maximo: 75<br>
# Raio Minimo: 73
#
# ##### Moeda 10 Centimos
# Raio Maximo: 70<br>
# Raio Minimo: 65
#
# ##### Moeda 20 Centimos
# Raio Maximo: 79<br>
# Raio Minimo: 75
#
# ##### Moeda 50 Centimos
# Raio Maximo: 85<br>
# Raio Minimo: 80
#
# ##### Moeda 1 Euro
# Raio Maximo: 81<br>
# Raio Minimo: 76

# %% [markdown]
# #### Valores Reais nas Imagens
# 1 - 2.08<br>
# 2 - 1.33<br>
# 3 - 0.78<br>
# 4 - 0.67<br>
# 5 - 1.62<br>
# 6 - 1.67<br>
# 7 - 1.3<br>
# 8 - 1.3<br>
# 9 -

# %% [markdown]
# #### Tentativa de Classificacao das Imagens

# %%
moeda0_01 = {"valor" : 0.01, "minRaio" : 54, "maxRaio" : 57} #
moeda0_02 = {"valor" : 0.02, "minRaio" : 64, "maxRaio" : 68} #
moeda0_05 = {"valor" : 0.05, "minRaio" : 73, "maxRaio" : 75} #
moeda0_10 = {"valor" : 0.1,  "minRaio" : 65, "maxRaio" : 70} #
moeda0_20 = {"valor" : 0.2,  "minRaio" : 75, "maxRaio" : 79} #
moeda0_50 = {"valor" : 0.5,  "minRaio" : 80, "maxRaio" : 85}
moeda1_00 = {"valor" : 1,    "minRaio" : 76, "maxRaio" : 81}

moedas = [moeda0_01, moeda0_02, moeda0_05, moeda0_10, moeda0_20, moeda0_50, moeda1_00]

print(moedas)

# %%
imagem1 = {}
imagem2 = {}
imagem3 = {}
imagem4 = {}
imagem5 = {}
imagem6 = {}
imagem7 = {}
imagem8 = {}
imagem9 = {}

imagensClassificadas = [imagem1, imagem2, imagem3, imagem4, imagem5, imagem6, imagem7, imagem8, imagem9]

# %%
def avaliarRaio(r):
    
    retorno = []
    
    if r >= 54 and r <= 57:
        retorno.append(moeda0_01)
    if r >= 64 and r <= 68:
        retorno.append(moeda0_02)
    if r >= 65 and r <= 70:
        retorno.append(moeda0_10)
    if r >= 73 and r <= 75:
        retorno.append(moeda0_05)
    if r >= 75 and r <= 79:
        retorno.append(moeda0_20)
    if r >= 76 and r <= 81:
        retorno.append(moeda1_00)
    if r >= 80 and r <= 85:
        retorno.append(moeda0_50)
    if r < 54 or r > 85:
        retorno.append(None)
        
    return retorno

# %%
numberOfImages = 9
imagensOriginais = [None] * numberOfImages
initialIndex = 1000697
currentIndex = initialIndex

### Carregar Imagens
for index in range(numberOfImages):
    while imagensOriginais[index] is None:
        imagensOriginais[index] = cv2.imread("P" + str(currentIndex) + "s.jpg")
        currentIndex = currentIndex + 1


### Imagens Grayscale
imagensGrayscale = [None] * numberOfImages

for index in range(numberOfImages):
    imagensGrayscale[index] = cv2.cvtColor(imagensOriginais[index], cv2.COLOR_BGR2GRAY)

# %%
for index in range(numberOfImages):

    circlesGrayscale = cv2.HoughCircles(imagensGrayscale[index], cv2.HOUGH_GRADIENT, 1.3, 90, minRadius=50, maxRadius=240)
    
    valorTotal = 0
    
    if circlesGrayscale is not None:
        circlesGrayscale = np.round(circlesGrayscale[0, :]).astype("int")
        
        for circleIndex in range(len(circlesGrayscale)):
            #print(x,y,r)
            (x, y, r) = circlesGrayscale[circleIndex, :]
            valorObtido = avaliarRaio(r)
            
            if len(valorObtido) == 1:
                if valorObtido[0] is not None:
                    imagensClassificadas[index].update({"valor" + str(circleIndex) : valorObtido[0].get("valor")})
                    valorTotal = valorTotal + valorObtido[0].get("valor")
                else:
                    imagensClassificadas[index].update({"valor" + str(circleIndex) : None})
            else:
                moeda = None
                minimo = 1000
                for moedaValorObtido in valorObtido:
                    if moedaValorObtido.get("maxRaio") - r < minimo:
                        minimo = moedaValorObtido.get("maxRaio") - r
                        moeda = moedaValorObtido
                imagensClassificadas[index].update({"valor" + str(circleIndex) : moeda.get("valor")})
                valorTotal = valorTotal + moeda.get("valor")
            
    imagensClassificadas[index].update({"valor total" : valorTotal})

print(imagensClassificadas[7])

# %% [markdown]
# ### Dicas do Jairo

# %%
for index in range(numberOfImages):
    blur = cv2.GaussianBlur(imagensGrayscale[index], (15, 15), 0)
    #blur = cv2.equalizeHist(blur)
    
    #showImage("", blur, True)
    
    circlesGrayscale = cv2.HoughCircles(blur, cv2.HOUGH_GRADIENT, 2, 90, minRadius=50, maxRadius=240)
    circlesCopy = imagensOriginais[index].copy()

    print("Index " + str(index + 1))
    
    if circlesGrayscale is not None:
        circlesGrayscale = np.round(circlesGrayscale[0, :]).astype("int")
        for (x, y, r) in circlesGrayscale:
            cv2.circle(circlesCopy, (x, y), r, (0, 0, 0), 4)

            print(x, y, r)
            #showImage("Imagem Blur" + str(index), imagensOriginais[index][y - r : y + r, x - r : x + r], True)
        #showImage("Imagem Blur" + str(index + 1), circlesCopy, True)
        print()

# %% [markdown]
# ### Apontamentos

# %% [markdown]
# Na primeira imagem, com blur: <br>
# - A moeda de 50 centimos fica PIOR.
# - A moeda de 1 euro fica MELHOR.
#
# De resto, fica tudo igual
#
# ##### Moeda 1 Centimo
# Raio Maximo: 58<br>
# Raio Minimo: 57
#
# ##### Moeda 2 Centimos
# Raio Maximo: 68<br>
# Raio Minimo: 65
#
# ##### Moeda 5 Centimos
# Raio Maximo: 77<br>
# Raio Minimo: 72
#
# ##### Moeda 10 Centimos
# Raio Maximo: 72<br>
# Raio Minimo: 68
#
# ##### Moeda 20 Centimos
# Raio Maximo: 79<br>
# Raio Minimo: 78
#
# ##### Moeda 50 Centimos
# Raio Maximo: 87<br>
# Raio Minimo: 85
#
# ##### Moeda 1 Euro
# Raio Maximo: 84<br>
# Raio Minimo: 81
#
# ###### Resumo
# 0.01 : 57 - 58<br>
# 0.02 : 65 - 68<br>
# 0.10 : 68 - 72<br>
# 0.05 : 72 - 77<br>
# 0.20 : 78 - 79<br>
# 1.00 : 81 - 84<br>
# 0.50 : 85 - 87

# %% [markdown]
# #### Valores Reais nas Imagens
# 1 - 2.08<br>
# 2 - 1.33<br>
# 3 - 0.78<br>
# 4 - 0.67<br>
# 5 - 1.62<br>
# 6 - 1.67<br>
# 7 - 1.3<br>
# 8 - 1.3<br>
# 9 - 1.7

# %% [markdown]
# #### Teste Classificacao Imagens

# %%
valoresReais = [2.08, 1.33, 0.78, 0.67, 1.62, 1.67, 1.3, 1.3, 1.7]

# %%
def avaliarRaio(r):
    
    if r >= 57 and r <= 58:
        return moeda0_01
    
    elif r >= 65 and r < 68:
        return moeda0_02
    
    elif r >= 68 and r < 72:
        return moeda0_10
    
    elif r >= 72 and r <= 77:
        return moeda0_05
    
    elif r >= 78 and r <= 79:
        return moeda0_20
    
    elif r >= 81 and r <= 84:
        return moeda1_00
    
    elif r >= 85 and r <= 87:
        return moeda0_50
    
    else:
        return None

# %%
for index in range(numberOfImages):

    blur = cv2.GaussianBlur(imagensGrayscale[index], (15, 15), 0)
    circlesGrayscale = cv2.HoughCircles(blur, cv2.HOUGH_GRADIENT, 2, 90, minRadius=50, maxRadius=240)
    circlesCopy = imagensOriginais[index].copy()
    valorTotal = 0
    
    if circlesGrayscale is not None:
        circlesGrayscale = np.round(circlesGrayscale[0, :]).astype("int")
        
        for circleIndex in range(len(circlesGrayscale)):
            #print(x,y,r)
            (x, y, r) = circlesGrayscale[circleIndex, :]

            valorObtido = avaliarRaio(r)
            
            if valorObtido is not None:
                imagensClassificadas[index].update({"valor" + str(circleIndex) : valorObtido.get("valor")})
                valorTotal = valorTotal + valorObtido.get("valor")
            else:
                imagensClassificadas[index].update({"valor" + str(circleIndex) : None})

        imagensClassificadas[index].update({"valor total" : valorTotal})

# %% [markdown]
# #### Impressão dos Resultados

# %%
for i in range(numberOfImages):
    print("Imagem " + str(i + 1) + ":")
    print("Valor Real: ", valoresReais[i])
    print("Valor Obtido: ", str(round(imagensClassificadas[i].get("valor total"), 2)))
    print()

# %%
moeda0_01 = {"valor" : 0.01, "minRaio" : 54, "maxRaio" : 57} #
moeda0_02 = {"valor" : 0.02, "minRaio" : 64, "maxRaio" : 68} #
moeda0_05 = {"valor" : 0.05, "minRaio" : 73, "maxRaio" : 75} #
moeda0_10 = {"valor" : 0.1,  "minRaio" : 65, "maxRaio" : 70} #
moeda0_20 = {"valor" : 0.2,  "minRaio" : 75, "maxRaio" : 79} #
moeda0_50 = {"valor" : 0.5,  "minRaio" : 80, "maxRaio" : 85}
moeda1_00 = {"valor" : 1,    "minRaio" : 76, "maxRaio" : 81}

moedas = [moeda0_01, moeda0_02, moeda0_05, moeda0_10, moeda0_20, moeda0_50, moeda1_00]

print(moedas)

# %%
def avaliarRaio(r):
    
    if r >= 57 and r <= 58:
        return moeda0_01
    
    elif r >= 65 and r < 68:
        return moeda0_02
    
    elif r >= 68 and r < 72:
        return moeda0_10
    
    elif r >= 72 and r <= 77:
        return moeda0_05
    
    elif r >= 78 and r <= 79:
        return moeda0_20
    
    elif r >= 81 and r <= 84:
        return moeda1_00
    
    elif r >= 85 and r <= 87:
        return moeda0_50
    
    else:
        return None

# %%
import cv2
import numpy as np

# %%
imagemOriginal = cv2.imread("P1000713s.jpg")
imagemGrayscale = cv2.cvtColor(imagemOriginal, cv2.COLOR_BGR2GRAY)

blur = cv2.GaussianBlur(imagemGrayscale, (15, 15), 0)
circlesGrayscale = cv2.HoughCircles(blur, cv2.HOUGH_GRADIENT, 2, 90, minRadius=50, maxRadius=240)
circlesCopy = imagemOriginal.copy()
valorTotal = 0

if circlesGrayscale is not None:
    circlesGrayscale = np.round(circlesGrayscale[0, :]).astype("int")

    for circleIndex in range(len(circlesGrayscale)):
        #print(x,y,r)
        (x, y, r) = circlesGrayscale[circleIndex, :]

        valorObtido = avaliarRaio(r)

        if valorObtido is not None:
            valorTotal = valorTotal + valorObtido.get("valor")
            print("Moeda " + str(valorObtido.get("valor")))
        else:
            print("Não é moeda")

print(valorTotal)

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## Métodos Auxiliares

# %%
def showImage(imageTitle, image, waitForKey):
    cv2.imshow(imageTitle, image)
    
    if waitForKey:
        cv2.waitKey()
        cv2.destroyAllWindows()
    
def showImageArray(tituloArray, arrayImagens):
    for index in range(len(arrayImagens)):
        if index == len(arrayImagens) - 1:
            showImage(tituloArray + ": " + str(index), arrayImagens[index], True)
        else:
            showImage(tituloArray + ": " + str(index), arrayImagens[index], False)
            
def classificadorMoedas(areaMoeda, imagemObjecto):
    
    #Moeda 0.01
    if areaMoeda > 7700 and areaMoeda <= 8100:
        return mascaras.get("moeda " + str(0.01))
    
    #Moeda 0.02
    if areaMoeda > 10900 and areaMoeda <= 11500:
        return mascaras.get("moeda " + str(0.02))
    
    #Moeda 0.10
    if areaMoeda > 12000 and areaMoeda <= 12900:
        return mascaras.get("moeda " + str(0.10))
    
    #A partir daqui, existem objectos com áreas semelhantes às das moedas
    
    #Moeda 0.05 e Objecto 1
    if areaMoeda > 13900 and areaMoeda <= 14600:
        
        #mascaraMoeda5Centimos = mascaras.get("moeda 0.05").get("mascara")
        #result = cv2.matchTemplate(imagemObjecto, mascaraMoeda5Centimos, cv2.TM_CCOEFF_NORMED)
    
        #print(np.where(result >= 0.90))
        #for locationIndex in range(len(locations[0])):
        return None
    
    
    
    
    
    
    
    
    
    if areaMoeda > 7700 and areaMoeda <= 8100:
        return mascaras.get("moeda " + str(0.01))
    if areaMoeda > 7700 and areaMoeda <= 8100:
        return mascaras.get("moeda " + str(0.01))
    if areaMoeda > 7700 and areaMoeda <= 8100:
        return mascaras.get("moeda " + str(0.01))
    #2 Euros
    if areaMoeda > 20000 and areaMoeda <= 23000:
        return mascaras.get("moeda " + str(0.01))

# %% [markdown]
# ## Carregar Imagens

# %%
numberOfImages = 9
imagensOriginais = [None] * numberOfImages
initialIndex = 1000697
currentIndex = initialIndex

for index in range(numberOfImages):
    while imagensOriginais[index] is None:
        imagensOriginais[index] = cv2.imread("P" + str(currentIndex) + "s.jpg")
        currentIndex = currentIndex + 1

# %% [markdown]
# ## Obter o Canal RED das Imagens

# %%
imagensCanalRED = [None] * numberOfImages

for index in range(numberOfImages):
    imagensCanalRED[index] = imagensOriginais[index][:, :, 2]

# %% [markdown]
# ## Obter Thresholds e Imagens Binárias

# %%
imagensBinarias = [None] * numberOfImages
imagensThresholds = [None] * numberOfImages

for index in range(numberOfImages):
    imagensThresholds[index], imagensBinarias[index] = cv2.threshold(imagensCanalRED[index], 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# %%
print(imagensThresholds)
# Out:
# [134.0, 140.0, 142.0, 117.0, 144.0, 144.0, 142.0, 119.0, 144.0]

# %%
imagensBinarias = [None] * numberOfImages
imagensThresholds = [None] * numberOfImages

for index in range(numberOfImages):
    imagensThresholds[index], imagensBinarias[index] = cv2.threshold(imagensCanalRED[index], 100, 255, cv2.THRESH_BINARY)

# %% [markdown]
# ## Elementos Estruturantes

# %%
maskClose = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
maskErode = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (15, 15))
maskDilate = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (11, 11))

# %% [markdown]
# ## Aplicação das Operações Morfológicas

# %%
imagensPosOperacoesMorfologicas = [None] * numberOfImages

for index in range(numberOfImages):
    imagensPosOperacoesMorfologicas[index] = cv2.erode(imagensBinarias[index], maskErode, iterations=4)
    imagensPosOperacoesMorfologicas[index] = cv2.dilate(imagensPosOperacoesMorfologicas[index], maskDilate, iterations=4)

# %% [markdown]
# ## Separar em Componentes

# %%
mascaras = {}

for index in range(numberOfImages):
    numLabels, labels, stats, centroids = cv2.connectedComponentsWithStats(imagensPosOperacoesMorfologicas[index], 8, cv2.CV_32S)

    #print("Image " + str(index))
    
    for i in range(numLabels):

        if i != 0:
            initialPointX = stats[i, cv2.CC_STAT_LEFT]
            initialPointY = stats[i, cv2.CC_STAT_TOP]
            width = stats[i, cv2.CC_STAT_WIDTH]
            height = stats[i, cv2.CC_STAT_HEIGHT]
            area = stats[i, cv2.CC_STAT_AREA]
            (centroidX, centroidY) = centroids[i]

            imageCut = imagensPosOperacoesMorfologicas[index][initialPointY : initialPointY + height, initialPointX : initialPointX + width]
            imageOriginal = imagensOriginais[index][initialPointY : initialPointY + height, initialPointX : initialPointX + width]
            
            mascaras.update({str(index) + " - " + str(i) : imageCut})
            
#             print(i)
#             print("Initial Point X: " + str(initialPointX) + " | Initial Point Y: " + str(initialPointY))
#             print("Width: " + str(width) + " | Height: " + str(height))
#             print("Area: " + str(area))
#             print("Centroid: " + str(centroidX) + ", " + str(centroidY))
#             print()
            
#             showImage(str(index) + " | " + str(i), imageCut, False)
#             showImage(str(index) + " | " + str(i) + " | Original", imageOriginal, True)
            
#             if i == numLabels - 1:
#                 showImage(str(index) + " | " + str(i), imageCut, True)
#             else:
#                 showImage(str(index) + " | " + str(i), imageCut, False)
#         print()

# %% [markdown]
# # Observações
#
# #### Moeda 1 centimo:
# - Minima Area: 8032
# - Maxima Area: 7869
#
# #### Moeda 2 centimos:
# - Minima Area: 11037
# - Maxima Area: 11376
#
# #### Moeda 5 centimos:
# - Minima Area: 14413
# - Maxima Area: 14028
#
# #### Moeda 10 centimos:
# - Minima Area: 12123
# - Maxima Area: 12696
#
# #### Moeda 20 centimos:
# - Minima Area: 15646
# - Maxima Area: 16397
#
# #### Moeda 50 centimos:
# - Minima Area: 19307
# - Maxima Area: 19767
#
# #### Moeda 1 euro:
# - Minima Area: 17531
# - Maxima Area: 18088
#
# #### Afia:
# - Area: 23954
# - Area: 23962
#
# #### Moeda Cortada:
# - Area: 3773
#
# #### 1:
# - Area: 14354
# - Area: 13541
#
# #### X:
# - Area: 19770
#
# #### Coroa:
# - Area: 16149
# - Area: 16908

# %% [markdown]
# ## Area das Moedas Ordenada
#
# #### Moeda 1 Centimo:
# - Area : 7869 - 8032
#
# #### Moeda 2 Centimos:
# - Area: 11037 - 11376
#
# #### Moeda 10 Centimos:
# - Area: 12123 - 12696
#
# #### Moeda 5 Centimos:
# - Area: 14028 - 14413
#
# #### Moeda 20 Centimos:
# - Area: 15646 - 16397
#
# #### Moeda 1 Euro:
# - Area: 17531 - 18088
#
# #### Moeda 50 Centimos:
# - Area: 19307 - 19767

# %% [markdown]
# ## Criação das Máscaras das Moedas

# %%
valorMoedasOrdenado = [0.01, 0.02, 0.10, 0.05, 0.20, 1.0, 0.50]
areaMoedasOrdenado = [7700, 10700, 12000, 13800, 15200, 17200, 19000]
mascaras = {}

for index in range(len(valorMoedasOrdenado)):
    moeda = {}
    raio = int(np.sqrt(areaMoedasOrdenado[index] / np.pi))
    
    moeda.update({"valor" : valorMoedasOrdenado[index]})
    moeda.update({"mascara" : cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (raio * 2, raio * 2)) * 255})
    
    mascaras.update({"moeda " + str(valorMoedasOrdenado[index]) : moeda})

# %% [markdown]
# ## Classficação das Moedas nas Imagens

# %% [markdown]
# ##### 3 - 5 : Afia
# ##### 6 - 5 : X
# ##### 7 - 4 : Afia
# ##### 8 - 1 : Coroa
# ##### 8 - 2 : Coroa

# %%
showImage("", imagensPosOperacoesMorfologicas[7], True)

# %%
for index in range(numberOfImages):
    numLabels, labels, stats, centroids = cv2.connectedComponentsWithStats(imagensPosOperacoesMorfologicas[index], 8, cv2.CV_32S)

    for i in range(numLabels):

        if i != 0:
            initialPointX = stats[i, cv2.CC_STAT_LEFT]
            initialPointY = stats[i, cv2.CC_STAT_TOP]
            width = stats[i, cv2.CC_STAT_WIDTH]
            height = stats[i, cv2.CC_STAT_HEIGHT]
            area = stats[i, cv2.CC_STAT_AREA]
            (centroidX, centroidY) = centroids[i]

            imageCut = imagensPosOperacoesMorfologicas[index][initialPointY : initialPointY + height, initialPointX : initialPointX + width]
            original = imagensOriginais[index][initialPointY : initialPointY + height, initialPointX : initialPointX + width]
            
            print(str(index) + " | " + str(i) + " : " + str(area))
            #showImage("O", original, False)
            #showImage("I", imageCut, True)
            
            
            #print(str(index) + " | " + str(i) + " | " + str(area))
            
            #print(mascaras.get("moedas 0.10"))
            
            if index == 0 and i == 1:
                classificadorMoedas(area, imageCut)
                
            if index == 6 and i == 2:
                classificadorMoedas(area, imageCut)
            
            if index == 7 and i == 1:
                classificadorMoedas(area, imageCut)
                
#             if a is None:
#                 print(str(index) + " | " + str(i))
#                 showImage(str(index) + " | " + str(i), imageCut, True)



                #result = cv2.matchShapes(mascaraMoeda, imageCut, 1, 0)
                #result = cv2.matchTemplate(mascaraMoeda, imageCut, cv2.TM_CCOEFF_NORMED)
                
                
                #Encontrar as localizações.
                #locations = np.where(result >= .90)
                
                #print(locations)
                
                #print("INDEX: " +str(index) + " | Objecto Na Imagem: " + str(i) + " | Mascara Moeda: " + str(valor) + " | Tamanho Mascara: " + str(mascaraMoeda.shape))
                #print(result)
                #print()
                
                #showImage("Mascara " + str(valorMoedasOrdenado[indexMoeda]), mascaraMoeda, True)
                #showImage("A avaliar", imageCut, True)
                
                
                #print(result)
# Out:
# 0 | 1 : 14250
# 0 | 2 : 7890
# 0 | 3 : 19218
# 0 | 4 : 11213
# 0 | 5 : 12038
# 0 | 6 : 16158
# 0 | 7 : 15734
# 0 | 8 : 17438
# 1 | 1 : 11136
# 1 | 2 : 12121
# 1 | 3 : 7759
# 1 | 4 : 15915
# 1 | 5 : 17509
# 2 | 1 : 19460
# 2 | 2 : 11113
# 2 | 3 : 7751
# 2 | 4 : 14163
# 2 | 5 : 15932
# 3 | 1 : 19100
# 3 | 2 : 10923
# 3 | 3 : 11937
# 3 | 4 : 13951
# 3 | 5 : 23706
# 4 | 1 : 11007
# 4 | 2 : 19196
# 4 | 3 : 12405
# 4 | 4 : 17584
# 5 | 1 : 19487
# 5 | 2 : 10997
# 5 | 3 : 14197
# 5 | 4 : 12431
# 5 | 5 : 17717
# 6 | 1 : 3790
# 6 | 2 : 14057
# 6 | 3 : 12175
# 6 | 4 : 17598
# 6 | 5 : 19468
# 6 | 6 : 15846
# 7 | 1 : 13541
# 7 | 2 : 12046
# 7 | 3 : 12176
# 7 | 4 : 23687
# 7 | 5 : 15570
# 7 | 6 : 16101
# 8 | 1 : 16777
# 8 | 2 : 17797
# 8 | 3 : 19102
# 8 | 4 : 15835

# %%
def classificadorMoedas(areaMoeda, imagemObjecto):
    
    #Moeda 0.01
    if areaMoeda > 7700 and areaMoeda <= 8100:
        return mascaras.get("moeda 0.01")
    
    #Moeda 0.02
    if areaMoeda > 10900 and areaMoeda <= 11500:
        return mascaras.get("moeda 0.02")
    
    #Moeda 0.10
    if areaMoeda > 12000 and areaMoeda <= 12900:
        return mascaras.get("moeda 0.10 ")
    
    #A partir daqui, existem objectos com áreas semelhantes às das moedas
    
    #Moeda 0.05 e Objecto 1
    if areaMoeda > 13200 and areaMoeda <= 14600:
        
        mascaraMoeda5Centimos = mascaras.get("moeda 0.05").get("mascara")
        result = cv2.matchTemplate(imagemObjecto, mascaraMoeda5Centimos, cv2.TM_CCOEFF_NORMED)
    
        matches = np.where(result >= 0.90)
        
        if len(matches[0]) > 0:
            return mascaras.get("moeda " + str(0.10))
        else:
            return None
    
    
    
    
    
    
    
    
    
    if areaMoeda > 7700 and areaMoeda <= 8100:
        return mascaras.get("moeda " + str(0.01))
    if areaMoeda > 7700 and areaMoeda <= 8100:
        return mascaras.get("moeda " + str(0.01))
    if areaMoeda > 7700 and areaMoeda <= 8100:
        return mascaras.get("moeda " + str(0.01))
    #2 Euros
    if areaMoeda > 20000 and areaMoeda <= 23000:
        return mascaras.get("moeda " + str(0.01))

# %% [markdown]
# Moeda 1 Centimo Area : 7869 - 8032 |||
# Moeda 2 Centimos Area: 11037 - 11376 |||
# Moeda 10 Centimos Area: 12123 - 12696 |||
# Moeda 5 Centimos Area: 14028 - 14413 |||
# Moeda 20 Centimos Area: 15646 - 16397 |||
# Moeda 1 Euro Area: 17531 - 18088 |||
# Moeda 50 Centimos Area: 19307 - 19767 |||
# Afia: 23954 - 23962 |||
# 1: 13760 - 14354 |||
# X: 19770 |||
# Coroa: 16149 - 16908
