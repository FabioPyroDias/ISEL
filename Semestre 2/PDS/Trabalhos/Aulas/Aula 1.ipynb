# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-100, 100)
y = 3 * x**2 + 25

# %%
plt.plot(x, y)
plt.plot(x, -y + 10000)

# %%
import scipy.io.wavfile as wav

# %%
sampleRate, audio = wav.read("pipocas11k.wav")

print("Tempo de Áudio: " + "{:.2f}".format(len(audio) / sampleRate) + "s")

plt.plot(audio)
# Out:
# Tempo de Áudio: 6.84s
