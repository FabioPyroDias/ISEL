# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
'''
X1real = 5 * np.cos(-np.pi / 3)
X1imag = 5 * np.sin(-np.pi / 3)

X2real = 4 * np.cos(-np.pi / 4)
X2imag = 4 * np.sin(-np.pi / 4)

X1X2real = X1real + X2real
X1X2imag = X1imag + X2imag

print(str(X1X2real) + " | " + str(X1X2imag))

A = np.sqrt(X1X2real ** 2 + X1X2imag ** 2)
phi = np.arctan(X1X2imag / X1X2real)

print(str(A) + " | " + str(phi))

t = np.arange(-0.01, 0.01, 0.0001)
y = A * np.cos(2 * np.pi * 100 * t + phi)

plt.plot(y)
'''

#Refazer usando as funções dos imaginários.
X1 = 5 * (np.cos(-np.pi / 3) + 1j * np.sin(-np.pi / 3))
X2 = 4 * (np.cos(-np.pi / 4) + 1j * np.sin(-np.pi / 4))

Y = X1 + X2

t = np.arange(-0.01, 0.01, 0.0001)
y = np.sqrt(Y.real ** 2 + Y.imag ** 2) * np.cos(2 * np.pi * 100 * t + np.arctan(Y.imag / Y.real))

plt.plot(t, y, 'r')
